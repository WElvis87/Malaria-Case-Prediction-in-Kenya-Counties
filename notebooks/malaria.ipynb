# %%
import pandas as pd

# %%
malaria = pd.read_csv("../data/malaria_raw.csv")

# %%
malaria.head()
# Out:
#    Unnamed: 0  period  year month   county          code  cases_under_5yo  \
# 0           0  22-Jan  2022   Jan  Baringo  KE_County_30              663
# 1           1  22-Feb  2022   Feb  Baringo  KE_County_30              805
# 2           2  22-Mar  2022   Mar  Baringo  KE_County_30              762
# 3           3  22-Apr  2022   Apr  Baringo  KE_County_30              597
# 4           4  22-May  2022   May  Baringo  KE_County_30              725
#
#    cases_over_5yo  total_cases  temp  rainfall  month_code  county_code
# 0            1975         2638    18     96.54           1           30
# 1            1759         2564    19     45.28           2           30
# 2            1370         2132    20     77.64           3           30
# 3            1146         1743    19    261.67           4           30
# 4            1700         2425    17    169.35           5           30

# %%
malaria.tail()
# Out:
#       Unnamed: 0  period  year month      county          code  \
# 1687        1687  24-Aug  2024   Aug  West Pokot  KE_County_24
# 1688        1688  24-Sep  2024   Sep  West Pokot  KE_County_24
# 1689        1689  24-Oct  2024   Oct  West Pokot  KE_County_24
# 1690        1690  24-Nov  2024   Nov  West Pokot  KE_County_24
# 1691        1691  24-Dec  2024   Dec  West Pokot  KE_County_24
#
#       cases_under_5yo  cases_over_5yo  total_cases  temp  rainfall  \
# 1687             2674            6152         8826    16    221.69
# 1688             2018            4622         6640    17    172.77
# 1689             1987            4859         6846    19     14.81
# 1690             1992            4850         6842    18    154.62
# 1691             1313            2335         3648    18      8.58
#
#       month_code  county_code
# 1687           8           24
# 1688           9           24
# 1689          10           24
# 1690          11           24
# ...

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1692 non-null   int64
#  1   period           1692 non-null   object
#  2   year             1692 non-null   int64
#  3   month            1692 non-null   object
#  4   county           1692 non-null   object
#  5   code             1692 non-null   object
#  6   cases_under_5yo  1692 non-null   int64
#  7   cases_over_5yo   1692 non-null   int64
#  8   total_cases      1692 non-null   int64
#  9   temp             1692 non-null   int64
#  10  rainfall         1692 non-null   float64
#  11  month_code       1692 non-null   int64
#  12  county_code      1692 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 172.0+ KB

# %%
malaria.describe()
# Out:
#         Unnamed: 0         year  cases_under_5yo  cases_over_5yo  \
# count  1692.000000  1692.000000       1692.00000     1692.000000
# mean    845.500000  2023.000000       1589.33156     5680.725177
# std     488.582644     0.816738       3136.03515    11314.806775
# min       0.000000  2022.000000          0.00000        2.000000
# 25%     422.750000  2022.000000         18.00000       87.000000
# 50%     845.500000  2023.000000        154.00000      580.500000
# 75%    1268.250000  2024.000000       1055.00000     4134.750000
# max    1691.000000  2024.000000      22961.00000    81891.000000
#
#          total_cases         temp     rainfall   month_code  county_code
# count    1692.000000  1692.000000  1692.000000  1692.000000   1692.00000
# mean     7270.056738    20.606383   112.583505     6.500000     24.00000
# std     14392.971601     4.032383   115.512939     3.453073     13.56867
# min         3.000000     6.000000     0.000000     1.000000      1.00000
# ...

# %%
malaria = malaria.rename(columns={"Confirmed Malaria (only Positive cases) <5 yrs" : "Cases(<5 yrs)"})

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1692 non-null   int64
#  1   period           1692 non-null   object
#  2   year             1692 non-null   int64
#  3   month            1692 non-null   object
#  4   county           1692 non-null   object
#  5   code             1692 non-null   object
#  6   cases_under_5yo  1692 non-null   int64
#  7   cases_over_5yo   1692 non-null   int64
#  8   total_cases      1692 non-null   int64
#  9   temp             1692 non-null   int64
#  10  rainfall         1692 non-null   float64
#  11  month_code       1692 non-null   int64
#  12  county_code      1692 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 172.0+ KB

# %%
malaria = malaria.rename(columns={"Confirmed Malaria (only Positive cases) >5 yrs" : "Cases(>5 yrs)"})

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1692 non-null   int64
#  1   period           1692 non-null   object
#  2   year             1692 non-null   int64
#  3   month            1692 non-null   object
#  4   county           1692 non-null   object
#  5   code             1692 non-null   object
#  6   cases_under_5yo  1692 non-null   int64
#  7   cases_over_5yo   1692 non-null   int64
#  8   total_cases      1692 non-null   int64
#  9   temp             1692 non-null   int64
#  10  rainfall         1692 non-null   float64
#  11  month_code       1692 non-null   int64
#  12  county_code      1692 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 172.0+ KB

# %%
malaria = malaria.rename(columns={"Confirmed Malaria Cases" : "Total Cases"})

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1692 non-null   int64
#  1   period           1692 non-null   object
#  2   year             1692 non-null   int64
#  3   month            1692 non-null   object
#  4   county           1692 non-null   object
#  5   code             1692 non-null   object
#  6   cases_under_5yo  1692 non-null   int64
#  7   cases_over_5yo   1692 non-null   int64
#  8   total_cases      1692 non-null   int64
#  9   temp             1692 non-null   int64
#  10  rainfall         1692 non-null   float64
#  11  month_code       1692 non-null   int64
#  12  county_code      1692 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 172.0+ KB

# %%
missing_values = malaria.loc[malaria.isnull().any(axis=1)]

# %%
missing_values.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, period, year, month, county, code, cases_under_5yo, cases_over_5yo, total_cases, temp, rainfall, month_code, county_code]
# Index: []

# %%
missing_values
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, period, year, month, county, code, cases_under_5yo, cases_over_5yo, total_cases, temp, rainfall, month_code, county_code]
# Index: []

# %%
missing_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       0 non-null      int64
#  1   period           0 non-null      object
#  2   year             0 non-null      int64
#  3   month            0 non-null      object
#  4   county           0 non-null      object
#  5   code             0 non-null      object
#  6   cases_under_5yo  0 non-null      int64
#  7   cases_over_5yo   0 non-null      int64
#  8   total_cases      0 non-null      int64
#  9   temp             0 non-null      int64
#  10  rainfall         0 non-null      float64
#  11  month_code       0 non-null      int64
#  12  county_code      0 non-null      int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 0.0+ bytes

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1692 non-null   int64
#  1   period           1692 non-null   object
#  2   year             1692 non-null   int64
#  3   month            1692 non-null   object
#  4   county           1692 non-null   object
#  5   code             1692 non-null   object
#  6   cases_under_5yo  1692 non-null   int64
#  7   cases_over_5yo   1692 non-null   int64
#  8   total_cases      1692 non-null   int64
#  9   temp             1692 non-null   int64
#  10  rainfall         1692 non-null   float64
#  11  month_code       1692 non-null   int64
#  12  county_code      1692 non-null   int64
# dtypes: float64(1), int64(8), object(4)
# memory usage: 172.0+ KB

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1692 non-null   int64
#  1   Period         1692 non-null   object
#  2   Year           1692 non-null   int64
#  3   Month          1692 non-null   object
#  4   County         1692 non-null   object
#  5   Code           1692 non-null   object
#  6   Cases(<5 yrs)  1692 non-null   int64
#  7   Cases(>5 yrs)  1692 non-null   int64
#  8   Total Cases    1692 non-null   int64
#  9   Temp(C)        1692 non-null   int64
#  10  Rainfall(mm)   1692 non-null   float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 145.5+ KB

# %%
missing_values = malaria[malaria.isnull().any(axis=1)]

# %%
missing_values
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Period, Year, Month, County, Code, Cases(<5 yrs), Cases(>5 yrs), Total Cases, Temp(C), Rainfall(mm)]
# Index: []

# %%
malaria.to_csv("./data/Malaria.csv")

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1692 non-null   int64
#  1   Period         1692 non-null   object
#  2   Year           1692 non-null   int64
#  3   Month          1692 non-null   object
#  4   County         1692 non-null   object
#  5   Code           1692 non-null   object
#  6   Cases(<5 yrs)  1692 non-null   int64
#  7   Cases(>5 yrs)  1692 non-null   int64
#  8   Total Cases    1692 non-null   int64
#  9   Temp(C)        1692 non-null   int64
#  10  Rainfall(mm)   1692 non-null   float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 145.5+ KB

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1692 non-null   int64
#  1   Period         1692 non-null   object
#  2   Year           1692 non-null   int64
#  3   Month          1692 non-null   object
#  4   County         1692 non-null   object
#  5   Code           1692 non-null   object
#  6   Cases(<5 yrs)  1692 non-null   int64
#  7   Cases(>5 yrs)  1692 non-null   int64
#  8   Total Cases    1692 non-null   int64
#  9   Temp(C)        1692 non-null   int64
#  10  Rainfall(mm)   1692 non-null   float64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 145.5+ KB

# %%
total_cases = malaria.groupby("County", as_index=False)["Total Cases"].sum()

# %%
total_cases
# Out:
#              County  Total Cases
# 0           Baringo       104975
# 1             Bomet         5509
# 2           Bungoma       879512
# 3             Busia       841629
# 4   Elgeyo Marakwet        32952
# 5              Embu         1989
# 6           Garissa         9699
# 7          Homa Bay       953684
# 8            Isiolo        12674
# 9           Kajiado        13928
# 10         Kakamega      1577695
# 11          Kericho       122226
# 12           Kiambu        13787
# 13           Kilifi       182466
# 14        Kirinyaga         1279
# 15            Kisii       170181
# 16           Kisumu      1148993
# 17            Kitui         1793
# 18            Kwale       290921
# 19         Laikipia         2799
# 20             Lamu          962
# 21         Machakos         8126
# 22          Makueni         2409
# 23          Mandera         7717
# 24         Marsabit         8272
# 25             Meru        11421
# 26           Migori      1606174
# ...

# %%
total_cases.to_csv("./data/Total Cases.csv")

# %%
max_cases = total_cases["Total Cases"].max()

# %%
min_cases = total_cases["Total Cases"].min()

# %%
max_cases
# Out:
# 1821080

# %%
min_cases
# Out:
# 650

# %%
max_county = total_cases[total_cases["Total Cases"] == max_cases]["County"]

# %%
max_county
# Out:
# 37    Siaya
# Name: County, dtype: object

# %%
min_county = total_cases[total_cases["Total Cases"] == min_cases]["County"]

# %%
min_county
# Out:
# 34    Nyandarua
# Name: County, dtype: object

# %%
siaya = malaria[malaria["County"] == "Siaya"].reset_index(drop=True)

# %%
siaya
# Out:
#     Unnamed: 0.1  Unnamed: 0  Period  Year Month County          Code  \
# 0           1332        1332  Jan-22  2022   Jan  Siaya  KE_County_41
# 1           1333        1333  Feb-22  2022   Feb  Siaya  KE_County_41
# 2           1334        1334  Mar-22  2022   Mar  Siaya  KE_County_41
# 3           1335        1335  Apr-22  2022   Apr  Siaya  KE_County_41
# 4           1336        1336  May-22  2022   May  Siaya  KE_County_41
# 5           1337        1337  Jun-22  2022   Jun  Siaya  KE_County_41
# 6           1338        1338  Jul-22  2022   Jul  Siaya  KE_County_41
# 7           1339        1339  Aug-22  2022   Aug  Siaya  KE_County_41
# 8           1340        1340  Sep-22  2022   Sep  Siaya  KE_County_41
# 9           1341        1341  Oct-22  2022   Oct  Siaya  KE_County_41
# 10          1342        1342  Nov-22  2022   Nov  Siaya  KE_County_41
# 11          1343        1343  Dec-22  2022   Dec  Siaya  KE_County_41
# ...

# %%
siaya.to_csv("./data/siaya.csv")

# %%
nyandarua = malaria[malaria["County"] == "Nyandarua"]

# %%
nyandarua
# Out:
#       Unnamed: 0.1  Unnamed: 0  Period  Year Month     County          Code  \
# 1224          1224        1224  Jan-22  2022   Jan  Nyandarua  KE_County_18
# 1225          1225        1225  Feb-22  2022   Feb  Nyandarua  KE_County_18
# 1226          1226        1226  Mar-22  2022   Mar  Nyandarua  KE_County_18
# 1227          1227        1227  Apr-22  2022   Apr  Nyandarua  KE_County_18
# 1228          1228        1228  May-22  2022   May  Nyandarua  KE_County_18
# 1229          1229        1229  Jun-22  2022   Jun  Nyandarua  KE_County_18
# 1230          1230        1230  Jul-22  2022   Jul  Nyandarua  KE_County_18
# 1231          1231        1231  Aug-22  2022   Aug  Nyandarua  KE_County_18
# 1232          1232        1232  Sep-22  2022   Sep  Nyandarua  KE_County_18
# 1233          1233        1233  Oct-22  2022   Oct  Nyandarua  KE_County_18
# 1234          1234        1234  Nov-22  2022   Nov  Nyandarua  KE_County_18
# ...

# %%
nyandarua.to_csv("./data/nyandarua.csv")

# %%
nyandarua["Temp(C)"].mean()
# Out:
# np.float64(19.63888888888889)

# %%
nyandarua["Rainfall(mm)"].mean()
# Out:
# np.float64(80.79694444444446)

# %%
max_cases = nyandarua["Total Cases"].max()

# %%
max_cases
# Out:
# 38

# %%
max_month = nyandarua[nyandarua["Total Cases"] == max_cases]["Period"]

# %%
max_month
# Out:
# 1228    May-22
# Name: Period, dtype: object

# %%
nyandarua.loc[nyandarua["Period"] == "May-22"]
# Out:
#       Unnamed: 0.1  Unnamed: 0  Period  Year Month     County          Code  \
# 1228          1228        1228  May-22  2022   May  Nyandarua  KE_County_18
#
#       Cases(<5 yrs)  Cases(>5 yrs)  Total Cases  Temp(C)  Rainfall(mm)
# 1228              9             29           38       20         26.81

# %%
max_rainfall = nyandarua["Rainfall(mm)"].max()

# %%
max_rainfall
# Out:
# 490.56

# %%
max_temp = nyandarua["Temp(C)"].max()

# %%
max_temp
# Out:
# 22

# %%
siaya
# Out:
#     Unnamed: 0.1  Unnamed: 0  Period  Year Month County          Code  \
# 0           1332        1332  Jan-22  2022   Jan  Siaya  KE_County_41
# 1           1333        1333  Feb-22  2022   Feb  Siaya  KE_County_41
# 2           1334        1334  Mar-22  2022   Mar  Siaya  KE_County_41
# 3           1335        1335  Apr-22  2022   Apr  Siaya  KE_County_41
# 4           1336        1336  May-22  2022   May  Siaya  KE_County_41
# 5           1337        1337  Jun-22  2022   Jun  Siaya  KE_County_41
# 6           1338        1338  Jul-22  2022   Jul  Siaya  KE_County_41
# 7           1339        1339  Aug-22  2022   Aug  Siaya  KE_County_41
# 8           1340        1340  Sep-22  2022   Sep  Siaya  KE_County_41
# 9           1341        1341  Oct-22  2022   Oct  Siaya  KE_County_41
# 10          1342        1342  Nov-22  2022   Nov  Siaya  KE_County_41
# 11          1343        1343  Dec-22  2022   Dec  Siaya  KE_County_41
# ...

# %%
min_rainfall = siaya["Rainfall(mm)"].mean()

# %%
min_rainfall
# Out:
# np.float64(180.49694444444447)

# %%
min_temp = siaya["Temp(C)"].mean()

# %%
min_temp
# Out:
# np.float64(22.61111111111111)

# %%
max_cases = siaya["Total Cases"].max()

# %%
max_cases
# Out:
# 95362

# %%
max_period = siaya[siaya["Total Cases"] == max_cases]["Period"]

# %%
max_period
# Out:
# 16    May-23
# Name: Period, dtype: object

# %%
siaya.loc[siaya["Period"] == "May-23"]
# Out:
#     Unnamed: 0.1  Unnamed: 0  Period  Year Month County          Code  \
# 16          1348        1348  May-23  2023   May  Siaya  KE_County_41
#
#     Cases(<5 yrs)  Cases(>5 yrs)  Total Cases  Temp(C)  Rainfall(mm)
# 16          19078          76284        95362       22         207.4

# %%
max_temp = siaya["Temp(C)"].max()

# %%
max_temp
# Out:
# 26

# %%
max_rainfall = siaya["Rainfall(mm)"].max()

# %%
max_rainfall
# Out:
# 560.0

# %%
min_cases = siaya["Total Cases"].min()

# %%
min_cases
# Out:
# 31975

# %%
siaya.loc[siaya["Total Cases"] == min_cases]
# Out:
#     Unnamed: 0.1  Unnamed: 0  Period  Year Month County          Code  \
# 27          1359        1359  Apr-24  2024   Apr  Siaya  KE_County_41
#
#     Cases(<5 yrs)  Cases(>5 yrs)  Total Cases  Temp(C)  Rainfall(mm)
# 27           7311          24664        31975       22        355.92

# %%
siaya.sort_values(by="Total Cases", ascending=False)
# Out:
#     Unnamed: 0.1  Unnamed: 0  Period  Year Month County          Code  \
# 16          1348        1348  May-23  2023   May  Siaya  KE_County_41
# 5           1337        1337  Jun-22  2022   Jun  Siaya  KE_County_41
# 17          1349        1349  Jun-23  2023   Jun  Siaya  KE_County_41
# 6           1338        1338  Jul-22  2022   Jul  Siaya  KE_County_41
# 29          1361        1361  Jun-24  2024   Jun  Siaya  KE_County_41
# 18          1350        1350  Jul-23  2023   Jul  Siaya  KE_County_41
# 4           1336        1336  May-22  2022   May  Siaya  KE_County_41
# 0           1332        1332  Jan-22  2022   Jan  Siaya  KE_County_41
# 12          1344        1344  Jan-23  2023   Jan  Siaya  KE_County_41
# 13          1345        1345  Feb-23  2023   Feb  Siaya  KE_County_41
# 19          1351        1351  Aug-23  2023   Aug  Siaya  KE_County_41
# 30          1362        1362  Jul-24  2024   Jul  Siaya  KE_County_41
# ...

# %%
malaria
# Out:
#       Unnamed: 0.1  Unnamed: 0  Period  Year Month      County          Code  \
# 0                0           0  Jan-22  2022   Jan     Baringo  KE_County_30
# 1                1           1  Feb-22  2022   Feb     Baringo  KE_County_30
# 2                2           2  Mar-22  2022   Mar     Baringo  KE_County_30
# 3                3           3  Apr-22  2022   Apr     Baringo  KE_County_30
# 4                4           4  May-22  2022   May     Baringo  KE_County_30
# ...            ...         ...     ...   ...   ...         ...           ...
# 1687          1687        1687  Aug-24  2024   Aug  West Pokot  KE_County_24
# 1688          1688        1688  Sep-24  2024   Sep  West Pokot  KE_County_24
# 1689          1689        1689  Oct-24  2024   Oct  West Pokot  KE_County_24
# 1690          1690        1690  Nov-24  2024   Nov  West Pokot  KE_County_24
# 1691          1691        1691  Dec-24  2024   Dec  West Pokot  KE_County_24
#
# ...

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   1692 non-null   int64
#  1   Unnamed: 0     1692 non-null   int64
#  2   Period         1692 non-null   object
#  3   Year           1692 non-null   int64
#  4   Month          1692 non-null   object
#  5   County         1692 non-null   object
#  6   Code           1692 non-null   object
#  7   Cases(<5 yrs)  1692 non-null   int64
#  8   Cases(>5 yrs)  1692 non-null   int64
#  9   Total Cases    1692 non-null   int64
#  10  Temp(C)        1692 non-null   int64
#  11  Rainfall(mm)   1692 non-null   float64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 158.8+ KB

# %%
malaria["Year"] = malaria["Year"].astype(str).astype("period[Y]")

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   1692 non-null   int64
#  1   Unnamed: 0     1692 non-null   int64
#  2   Period         1692 non-null   object
#  3   Year           1692 non-null   period[Y-DEC]
#  4   Month          1692 non-null   object
#  5   County         1692 non-null   object
#  6   Code           1692 non-null   object
#  7   Cases(<5 yrs)  1692 non-null   int64
#  8   Cases(>5 yrs)  1692 non-null   int64
#  9   Total Cases    1692 non-null   int64
#  10  Temp(C)        1692 non-null   int64
#  11  Rainfall(mm)   1692 non-null   float64
# dtypes: float64(1), int64(6), object(4), period[Y-DEC](1)
# memory usage: 158.8+ KB

# %%
malaria
# Out:
#       Unnamed: 0.1  Unnamed: 0  Period  Year Month      County          Code  \
# 0                0           0  Jan-22  2022   Jan     Baringo  KE_County_30
# 1                1           1  Feb-22  2022   Feb     Baringo  KE_County_30
# 2                2           2  Mar-22  2022   Mar     Baringo  KE_County_30
# 3                3           3  Apr-22  2022   Apr     Baringo  KE_County_30
# 4                4           4  May-22  2022   May     Baringo  KE_County_30
# ...            ...         ...     ...   ...   ...         ...           ...
# 1687          1687        1687  Aug-24  2024   Aug  West Pokot  KE_County_24
# 1688          1688        1688  Sep-24  2024   Sep  West Pokot  KE_County_24
# 1689          1689        1689  Oct-24  2024   Oct  West Pokot  KE_County_24
# 1690          1690        1690  Nov-24  2024   Nov  West Pokot  KE_County_24
# 1691          1691        1691  Dec-24  2024   Dec  West Pokot  KE_County_24
#
# ...

# %%
malaria["month_code"] = malaria["Month"].apply(lambda x: {
    "January": 1, "February": 2, "March": 3, "April": 4,
    "May": 5, "June": 6, "July": 7, "August": 8,
    "September": 9, "October": 10, "November": 11, "December": 12,
    "Jan": 1, "Feb": 2, "Mar": 3, "Apr": 4,
    "Jun": 6, "Jul": 7, "Aug": 8, "Sep": 9,
    "Oct": 10, "Nov": 11, "Dec": 12
}.get(x.strip(), None))

# %%
malaria
# Out:
#       Unnamed: 0.1  Unnamed: 0  Period  Year Month      County          Code  \
# 0                0           0  Jan-22  2022   Jan     Baringo  KE_County_30
# 1                1           1  Feb-22  2022   Feb     Baringo  KE_County_30
# 2                2           2  Mar-22  2022   Mar     Baringo  KE_County_30
# 3                3           3  Apr-22  2022   Apr     Baringo  KE_County_30
# 4                4           4  May-22  2022   May     Baringo  KE_County_30
# ...            ...         ...     ...   ...   ...         ...           ...
# 1687          1687        1687  Aug-24  2024   Aug  West Pokot  KE_County_24
# 1688          1688        1688  Sep-24  2024   Sep  West Pokot  KE_County_24
# 1689          1689        1689  Oct-24  2024   Oct  West Pokot  KE_County_24
# 1690          1690        1690  Nov-24  2024   Nov  West Pokot  KE_County_24
# 1691          1691        1691  Dec-24  2024   Dec  West Pokot  KE_County_24
#
# ...

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   1692 non-null   int64
#  1   Unnamed: 0     1692 non-null   int64
#  2   Period         1692 non-null   object
#  3   Year           1692 non-null   period[Y-DEC]
#  4   Month          1692 non-null   object
#  5   County         1692 non-null   object
#  6   Code           1692 non-null   object
#  7   Cases(<5 yrs)  1692 non-null   int64
#  8   Cases(>5 yrs)  1692 non-null   int64
#  9   Total Cases    1692 non-null   int64
#  10  Temp(C)        1692 non-null   int64
#  11  Rainfall(mm)   1692 non-null   float64
#  12  month_code     1692 non-null   int64
# dtypes: float64(1), int64(7), object(4), period[Y-DEC](1)
# memory usage: 172.0+ KB

# %%
malaria["county_code"] = malaria["Code"].apply(lambda x: x.split("_")[-1])

# %%
malaria
# Out:
#       Unnamed: 0.1  Unnamed: 0  Period  Year Month      County          Code  \
# 0                0           0  Jan-22  2022   Jan     Baringo  KE_County_30
# 1                1           1  Feb-22  2022   Feb     Baringo  KE_County_30
# 2                2           2  Mar-22  2022   Mar     Baringo  KE_County_30
# 3                3           3  Apr-22  2022   Apr     Baringo  KE_County_30
# 4                4           4  May-22  2022   May     Baringo  KE_County_30
# ...            ...         ...     ...   ...   ...         ...           ...
# 1687          1687        1687  Aug-24  2024   Aug  West Pokot  KE_County_24
# 1688          1688        1688  Sep-24  2024   Sep  West Pokot  KE_County_24
# 1689          1689        1689  Oct-24  2024   Oct  West Pokot  KE_County_24
# 1690          1690        1690  Nov-24  2024   Nov  West Pokot  KE_County_24
# 1691          1691        1691  Dec-24  2024   Dec  West Pokot  KE_County_24
#
# ...

# %%
malaria.to_csv("./data/Malaria.csv")

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   1692 non-null   int64
#  1   Unnamed: 0     1692 non-null   int64
#  2   Period         1692 non-null   object
#  3   Year           1692 non-null   period[Y-DEC]
#  4   Month          1692 non-null   object
#  5   County         1692 non-null   object
#  6   Code           1692 non-null   object
#  7   Cases(<5 yrs)  1692 non-null   int64
#  8   Cases(>5 yrs)  1692 non-null   int64
#  9   Total Cases    1692 non-null   int64
#  10  Temp(C)        1692 non-null   int64
#  11  Rainfall(mm)   1692 non-null   float64
#  12  month_code     1692 non-null   int64
#  13  county_code    1692 non-null   object
# dtypes: float64(1), int64(7), object(5), period[Y-DEC](1)
# memory usage: 185.2+ KB

# %%
malaria["county_code"] = pd.to_numeric(malaria["county_code"])

# %%
malaria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   1692 non-null   int64
#  1   Unnamed: 0     1692 non-null   int64
#  2   Period         1692 non-null   object
#  3   Year           1692 non-null   period[Y-DEC]
#  4   Month          1692 non-null   object
#  5   County         1692 non-null   object
#  6   Code           1692 non-null   object
#  7   Cases(<5 yrs)  1692 non-null   int64
#  8   Cases(>5 yrs)  1692 non-null   int64
#  9   Total Cases    1692 non-null   int64
#  10  Temp(C)        1692 non-null   int64
#  11  Rainfall(mm)   1692 non-null   float64
#  12  month_code     1692 non-null   int64
#  13  county_code    1692 non-null   int64
# dtypes: float64(1), int64(8), object(4), period[Y-DEC](1)
# memory usage: 185.2+ KB
# The Kernel crashed while executing code in the current cell or a previous cell.
# ...
